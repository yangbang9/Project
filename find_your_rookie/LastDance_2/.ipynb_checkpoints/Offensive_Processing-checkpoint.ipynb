# %%
import pandas as pd
import numpy as np

# df = pd.read_csv("./data/EPL_13_14/offensive.csv")
# df = pd.read_csv("./data/La_13-14/offensive.csv")
# df = pd.read_csv("./data/Bun_13-14/offensive.csv")
# df = pd.read_csv("./data/Li1_13-14/offensive.csv")
# df = pd.read_csv("./data/Se_13-14/offensive.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  300 non-null    int64
#  1   name        300 non-null    object
#  2   age         300 non-null    int64
#  3   position1   300 non-null    object
#  4   position2   88 non-null     object
#  5   Apps        300 non-null    object
#  6   Mins        300 non-null    int64
#  7   Goals       300 non-null    object
#  8   Assists     300 non-null    object
#  9   SpG         300 non-null    object
#  10  KeyP        300 non-null    object
#  11  Drb         300 non-null    object
#  12  Fouled      300 non-null    object
#  13  Off         300 non-null    object
#  14  Disp        300 non-null    object
#  15  UnsTch      300 non-null    object
#  16  Rating      300 non-null    float64
# dtypes: float64(1), int64(3), object(13)
# memory usage: 40.0+ KB

# %%
df1 = df[["name","age","position1","position2", "Apps","Mins", "Goals", "Assists", "SpG","KeyP", "Drb", "Rating" ]]
df1['WC_Rating'] = 0
df1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25812\434650812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['WC_Rating'] = 0
#                                name  age position1 position2    Apps  Mins  \
# 0            Lionel Messi Barcelona   35    AM(CR)        FW   29(2)  2508
# 1     Cristiano Ronaldo Real Madrid   37      M(L)        FW      30  2545
# 2         Sergio Álvarez Celta Vigo   36        GK       NaN       3   270
# 3           Gareth Bale Real Madrid   33    M(CLR)        FW   24(3)  2073
# 4              Ivan Rakitic Sevilla   34      M(C)       NaN   29(4)  2676
# ..                              ...  ...       ...       ...     ...   ...
# 295  Imanol Agirretxe Real Sociedad   35        FW       NaN  21(10)  1960
# 296           Álex López Celta Vigo   34      M(C)       NaN   24(7)  2015
# 297              José Gayà Valencia   27      D(L)      M(L)       1    90
# 298         Raúl Rodríguez Espanyol   35     D(CR)       DMC   12(5)  1134
# 299    Aleksandar Pantic Villarreal   30      D(C)       NaN    6(1)   506
#
#     Goals Assists  SpG KeyP  Drb  Rating  WC_Rating
# 0      27      11    5  2.4  4.6    8.34          0
# 1      31       9  7.2  1.6  2.2    8.27          0
# 2       -       -    -    -    -    8.26          0
# 3      15      12  3.3  1.5  2.1    7.75          0
# 4      11      10  2.3  2.3  0.8    7.61          0
# ..    ...     ...  ...  ...  ...     ...        ...
# 295     8       1    2  0.4  0.4    6.67          0
# 296     5       2  1.6  0.8  0.7    6.66          0
# 297     -       -    -    1    3    6.66          0
# 298     -       -  0.3  0.1    -    6.66          0
# 299     -       -  0.1    -    -    6.66          0
#
# [300 rows x 13 columns]

# %%
# ## 25세 이하 선수들 df2

# idx_age = df1[df1['age'] > 26].index
# df2 = df1.drop(idx_age)

# %%
## 출전 경기, 선발과 교체로 분할

df_app = df1[['Apps']]
df_app['start'] = df_app.Apps.str.split('(').str[0]
df_app['sub'] = df_app.Apps.str.split('(').str[1];
df_app['sub'] = df_app['sub'].replace('[\),]','', regex=True)
df_app = df_app.fillna(0)
df_app
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25812\731944388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_app['start'] = df_app.Apps.str.split('(').str[0]
# C:\Users\user\AppData\Local\Temp\ipykernel_25812\731944388.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_app['sub'] = df_app.Apps.str.split('(').str[1];
# C:\Users\user\AppData\Local\Temp\ipykernel_25812\731944388.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_app['sub'] = df_app['sub'].replace('[\),]','', regex=True)
#        Apps start sub
# 0     29(2)    29   2
# 1        30    30   0
# 2         3     3   0
# 3     24(3)    24   3
# 4     29(4)    29   4
# ..      ...   ...  ..
# 295  21(10)    21  10
# 296   24(7)    24   7
# 297       1     1   0
# 298   12(5)    12   5
# 299    6(1)     6   1
#
# [300 rows x 3 columns]

# %%
df1 = df1.replace('-',0)
## 데이터 타입 형변환 (object > 정수형)
df_app['start'] = df_app['start'].astype(int)
df_app['sub'] = df_app['sub'].astype(int)
df_app.dtypes


df1['Mins'] = df1['Mins'].astype(float)
df1['Goals'] = df1['Goals'].astype(float)
df1['Assists'] = df1['Assists'].astype(float)
df1['SpG'] = df1['SpG'].astype(float)
df1['KeyP'] = df1['KeyP'].astype(float)
df1['Drb'] = df1['Drb'].astype(float)
df1['Rating'] = df1['Rating'].astype(float)
df1.dtypes
# Out:
# name          object
# age            int64
# position1     object
# position2     object
# Apps          object
# Mins         float64
# Goals        float64
# Assists      float64
# SpG          float64
# KeyP         float64
# Drb          float64
# Rating       float64
# WC_Rating      int64
# dtype: object

# %%
# ## 25세 이하 / 출전경기 19경기 이상인 선수
# df_app2 = pd.DataFrame(df_app.sum(axis=1))
# df_app2.columns = ["Apps"]

# idx_app = df_app2[df_app2['Apps'] < 19].index
# df_app3 = df_app2.drop(idx_app)
# df_app3

# %%
df4 = df1.fillna('')
#포지션별 분류
df5 = ((df4['position1'].str.contains('AM'))|df4['position1'].str.contains('FW')
      |df4['position2'].str.contains('AM')|df4['position2'].str.contains('FW'))
df6 = pd.DataFrame(df5)
df6.columns = ["Position"]
df6['Position'] = df6['Position'].astype(int)
df6
# Out:
#      Position
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# ..        ...
# 295         1
# 296         0
# 297         0
# 298         0
# 299         0
#
# [300 rows x 1 columns]

# %%
#포지션이 공격수/ 공격형 미드필더

idx_position = df6[df6['Position'] == 0].index
df_position = df6.drop(idx_position)
df_position
df7 = df1.loc[df_position.index]
df7 = df7.fillna('')
df7
# Out:
#                                 name  age position1 position2    Apps    Mins  \
# 0             Lionel Messi Barcelona   35    AM(CR)        FW   29(2)  2508.0
# 1      Cristiano Ronaldo Real Madrid   37      M(L)        FW      30  2545.0
# 3            Gareth Bale Real Madrid   33    M(CLR)        FW   24(3)  2073.0
# 6           Alexis Sánchez Barcelona   33    M(CLR)        FW   27(7)  2386.0
# 7                   Neymar Barcelona   30   AM(CLR)        FW   19(7)  1742.0
# 13        Ángel Di María Real Madrid   34    M(CLR)        FW   27(7)  2384.0
# 15         Karim Benzema Real Madrid   34        FW             34(1)  2779.0
# 19         Carlos Vela Real Sociedad   33    M(CLR)        FW   35(2)  3116.0
# 21                  Isco Real Madrid   30    M(CLR)        FW   23(9)  2001.0
# 23              Diego Costa Atletico   34        FW             34(1)  2965.0
# 30           Cesc Fàbregas Barcelona   35     M(CL)        FW   28(7)  2446.0
# 31      Aritz Aduriz Athletic Bilbao   41        FW             26(5)  2410.0
# 42      Iker Muniain Athletic Bilbao   29   AM(CLR)             32(3)  2730.0
# 43   Antoine Griezmann Real Sociedad   31   AM(CLR)        FW   31(4)  2666.0
# 47           Jonathan Viera Valencia   33   AM(CLR)        FW       1    79.0
# 65                 Nolito Celta Vigo   36    AM(CL)            24(11)  2264.0
# 67                   Pedro Barcelona   35    M(CLR)        FW   28(9)  2367.0
# 74        Fabián Orellana Celta Vigo   36   AM(CLR)             22(8)  1956.0
# 90               Oriol Riera Osasuna   36        FW             35(2)  3022.0
# 98     Giovani dos Santos Villarreal   33   AM(CLR)        FW   26(4)  2205.0
# 102               Charles Celta Vigo   38        FW             29(1)  2349.0
# 106             Carlos Bacca Sevilla   36        FW             27(7)  2290.0
# 111            Nordin Amrabat Malaga   35    M(CLR)        FW      15  1314.0
# 112           Sergio García Espanyol   39    M(CLR)        FW      37  3259.0
# 115                      Miku Getafe   37        FW              3(2)   292.0
# 120        Ikechukwu Uche Villarreal   38        FW             19(7)  1657.0
# 124                   Vitolo Sevilla   33    M(CLR)        FW   25(4)  2198.0
# 125             Raúl García Atletico   36    M(CLR)        FW  18(16)  1710.0
# 131      Javi Guerra Real Valladolid   40        FW                37  3161.0
# 132              Arda Turan Atletico   35   AM(CLR)             22(8)  1932.0
# 137       Ibai Gómez Athletic Bilbao   32    AM(LR)             6(12)   685.0
# 141        Cristhian Stuani Espanyol   36   AM(CLR)        FW   28(6)  2574.0
# 149         Javier Aquino Villarreal   32     AM(R)             18(9)  1695.0
# 155          Roque Santa Cruz Malaga   41        FW             24(7)  2140.0
# 161      Emiliano Armenteros Osasuna   36   AM(CLR)             27(2)  2248.0
# 176         Youssef El Arabi Granada   35     AM(C)        FW   34(2)  2801.0
# 182                   Jonas Valencia   38   AM(CLR)        FW   23(8)  2097.0
# 188             David Villa Atletico   40     AM(L)        FW   32(4)  2431.0
# 190           Fede Cartabia Valencia   29   AM(CLR)             16(9)  1423.0
# 191  Joaquín Larrivey Rayo Vallecano   38        FW            24(11)  2415.0
# 202             Manu Molina Espanyol   30     AM(R)              0(1)    31.0
# 206             David Barral Levante   39        FW             25(7)  2255.0
# 207           Roberto Torres Osasuna   33   AM(CLR)             25(8)  2282.0
# 213                     Suso Almeria   28   AM(CLR)        FW   26(7)  2265.0
# 234            Diego Perotti Sevilla   34    M(CLR)        FW    3(7)   403.0
# 235        Manu Trigueros Villarreal   31    M(CLR)        FW  23(10)  2017.0
# 242          Rubén Castro Real Betis   41    AM(LR)        FW   22(3)  2019.0
# 248              Ángel Lafita Getafe   38    M(CLR)        FW   22(7)  1870.0
# 249       Iago Falque Rayo Vallecano   32   AM(CLR)        FW   26(2)  2001.0
# 258            Kevin Gameiro Sevilla   35        FW            20(15)  1890.0
# 263        Kike Sola Athletic Bilbao   36        FW              2(3)   226.0
# 274          Jorge Molina Real Betis   40        FW             25(7)  2352.0
# 275    Jonathan Viera Rayo Vallecano   33   AM(CLR)        FW   18(8)  1725.0
# 276     Gonzalo Castro Real Sociedad   38    AM(LR)        FW  12(11)  1022.0
# 281            Dorlan Pabón Valencia   34   AM(CLR)        FW   11(2)   913.0
# 282                 Carles Gil Elche   29    AM(CR)             29(3)  2524.0
# 284         Víctor Casadesús Levante   37     AM(C)        FW   13(1)  1051.0
# 293            Paco Alcácer Valencia   29     AM(R)        FW   17(6)  1542.0
# 295   Imanol Agirretxe Real Sociedad   35        FW            21(10)  1960.0
#
#      Goals  Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 0     27.0     11.0  5.0   2.4  4.6    8.34          0
# 1     31.0      9.0  7.2   1.6  2.2    8.27          0
# 3     15.0     12.0  3.3   1.5  2.1    7.75          0
# 6     19.0     10.0  1.9   1.4  1.1    7.54          0
# 7      9.0      8.0  2.6   1.6  3.0    7.51          0
# 13     4.0     17.0  1.8   2.6  1.4    7.46          0
# 15    17.0      9.0  2.9   1.8  0.5    7.44          0
# 19    15.0     12.0  2.2   2.1  2.0    7.42          0
# 21     8.0      6.0  1.4   2.2  2.1    7.41          0
# 23    27.0      3.0  3.1   1.3  1.7    7.40          0
# 30     8.0     12.0  1.4   1.6  0.7    7.32          0
# 31    15.0      7.0  2.6   1.0  0.7    7.32          0
# 42     7.0      3.0  1.5   0.9  2.7    7.23          0
# 43    16.0      3.0  3.2   1.0  0.6    7.22          0
# 47     0.0      0.0  1.0   0.0  5.0    7.21          0
# 65    12.0      2.0  2.3   1.4  1.3    7.13          0
# 67    15.0      8.0  1.9   1.0  0.7    7.13          0
# 74     5.0      6.0  1.3   1.5  1.4    7.10          0
# 90    13.0      0.0  2.1   0.9  0.4    7.05          0
# 98    10.0      8.0  1.9   1.4  0.9    7.03          0
# 102   12.0      3.0  2.2   1.1  0.3    7.02          0
# 106   14.0      5.0  1.9   1.0  0.9    7.01          0
# 111    2.0      4.0  2.1   1.7  2.3    7.00          0
# 112   11.0      8.0  2.0   1.9  1.8    7.00          0
# 115    2.0      1.0  1.2   0.8  0.8    6.99          0
# 120   13.0      2.0  1.6   0.9  0.4    6.98          0
# 124    4.0      6.0  1.1   1.3  1.1    6.97          0
# 125    9.0      3.0  1.8   0.5  0.2    6.97          0
# 131   15.0      1.0  2.3   0.6  0.4    6.96          0
# 132    3.0      4.0  1.1   1.1  1.3    6.96          0
# 137    8.0      2.0  2.6   1.3  0.7    6.94          0
# 141    6.0      2.0  1.5   0.6  0.6    6.94          0
# 149    1.0      4.0  0.7   1.0  1.1    6.93          0
# 155    6.0      2.0  1.6   1.0  0.6    6.92          0
# 161    4.0      3.0  1.5   1.7  0.8    6.91          0
# 176   12.0      2.0  2.6   0.8  0.9    6.88          0
# 182   10.0      1.0  2.8   0.7  0.6    6.86          0
# 188   13.0      4.0  2.1   0.8  0.3    6.85          0
# 190    0.0      1.0  1.8   1.1  1.6    6.85          0
# 191   12.0      4.0  1.9   0.7  0.1    6.85          0
# 202    0.0      1.0  0.0   2.0  0.0    6.83          0
# 206    7.0      0.0  2.0   0.7  0.6    6.82          0
# 207    5.0      3.0  1.6   1.8  0.5    6.82          0
# 213    3.0      7.0  1.9   1.0  1.7    6.81          0
# 234    1.0      1.0  1.1   1.0  1.6    6.77          0
# 235    1.0      1.0  1.0   0.9  0.5    6.76          0
# 242   10.0      1.0  3.0   1.0  0.6    6.76          0
# 248    7.0      1.0  1.4   0.7  1.0    6.75          0
# 249    3.0      2.0  1.4   1.3  0.7    6.75          0
# 258   14.0      3.0  1.5   0.8  0.5    6.73          0
# 263    1.0      0.0  1.4   0.0  0.6    6.72          0
# 274    9.0      1.0  1.8   1.1  0.4    6.69          0
# 275    5.0      7.0  1.9   1.4  1.2    6.69          0
# 276    2.0      3.0  1.0   1.1  1.2    6.69          0
# 281    3.0      0.0  2.8   0.8  0.8    6.69          0
# 282    1.0      3.0  1.0   1.3  1.6    6.69          0
# 284    1.0      2.0  1.1   0.8  1.0    6.69          0
# 293    6.0      2.0  1.9   0.7  0.1    6.67          0
# 295    8.0      1.0  2.0   0.4  0.4    6.67          0

# %%
Laliga_list = [
    'Real Madrid',
    'Barcelona',
    'Real Betis',
    'Deportivo Alaves',
    'Athletic Bilbao',
    'Celta Vigo',
    'Villarreal',
    'Real Sociedad',
    'Atletico',
    'Espanyol',
    'Rayo Vallecano',
    'Getafe',
    'Valencia',
    'Sevilla',
    'Levante',
    'Osasuna',
    'Mallorca',
    'Elche',
    'Granada',
    'Cadiz',
    'Eibar',
    'Leganes',
    'Girona',
    'SD Huesca',
    'Real Valladolid',
    'Malaga',
    'Las Palmas',
    'Deportivo',
    'Almeria',
    'Elche',
    'Real Zaragoza',
    'Sporting Gijon',
    'Racing Santnader',
    'Tenerife',
    'Xerez'
    

]
Country = [
    'Argentina',
    'Algeria',
    'Brazil',
    'Belgium',
    'Bosnia and Herzegovina',
    'Croatia',
    'Costa Rica',
    'Colombia',
    'Cameroon',
    'Chile',
    'Denmark',
    'Egypt',
    'England',
    'Ecuador',
    'France',
    'Germany',
    'Ghana',
    'Greece',
    'Honduras',
    'Iran',
    'Iceland',
    'Ivory Coast',
    'Italy',
    'Japan',
    'Morocco',
    'Mexico',
    'Nigieria',
    'Netherlands',
    'New Zealand',
    'North Korea',
    'Saudi Arabia',
    'Spain',
    'Switzerland',
    'Serbia',
    'Sweden',
    'South Korea',
    'Senegal',
    'South Africa',
    'Slovenia',
    'Serbia',
    'Slovakia',
    'Uruguay',
    'Russia',
    'Portugal',
    'Peru',
    'Tunisia',
    'Panama',
    'Poland',
    'USA',
    'Russia',
    'Paraguay'
    
]

EPL_list = [
    'Man Utd',
    'Man City',
    'Liverpool',
    'Tottenham',
    'Brentford',
    'Chelsea',
    'Aston Villa',
    'West Ham',
    'Newcastle',
    'Crystal Palace',
    'Leicester',
    'Southampton',
    'Brighton',
    'Burnley',
    'Wolves',
    'Leeds',
    'Everton',
    'Arsenal',
    'Watford',
    'Norwich',
    'Burnley',
    'Stoke',
    'Southampton',
    'Bournemouth',
    'West Brom',
    'Huddersfield',
    'Swansea',
    'Cardiff',
    'Sunderland',
    'Hull',
    'Fulham',
    'Norwich',
    'Birmingham',
    'Bolton',
    'Wigan',
    'Blackburn',
    'Portsmouth'
    
]
Seria_list = [
    'Sassuolo',
    'AC Milan',
    'Lazio',
    'Roma',
    'Fiorentina',
    'Atalanta',
    'Inter',
    'Napoli',
    'Juventus',
    'Torino',
    'Verona',
    'Udinese',
    'Salernitana',
    'Sampdoria',
    'Empoli',
    'Bologna',
    'Venezia',
    'Genoa',
    'Cagliari',
    'Salernitana',
    'SPAL 2013',
    'Chievo',
    'Crotone',
    'Benevento',
    'Parma Calcio 1913',
    'Livorno',
    'Catania',
    'Siena',
    'Bari',
    
    
]
Ligue1_list = [
    'PSG',
    'Rennes',
    'Lille',
    'Lorient', 
    'Lyon',
    'Lens',
    'Monaco',
    'Troyes',
    'Bordeaux',
    'Angers',
    'Marseille',
    'Nantes',
    'Montpellier',
    'Nice',
    'Brest',
    'Reims',
    'Clermont Foot',
    'Starsbourg',
    'Saint-Etienne',
    'Metz',
    'Toulouse',
    'SC Bastia',
    'Guingamp',
    'Evian',
    'Valenciennes',
    'AC Ajaccio'

]
Bundesliga_list = [
    'Bayern',
    'Borussia Dortmund',
    'Borussia M.Gladbach',
    'RBL',
    'Ausburg',
    'Freiburg',
    'Eintracht Frankfurt',
    'Wolfsburg',
    'Hertha Berlin',
    'FC Koln',
    'Shuttgart',
    'Bochum',
    'Mainz',
    'Union Berlin',
    'Hoffenheim',
    'Leverkusen',
    'Greuther Fuerto',
    'Arminia Bielefeld',
    'Hamburg',
    'Hannover',
    'Werder Bremen',
    'Schalke',
    'Augsburg',
    'Stuttgart',
    'Nuernberg',
    'Braunschweig',
    'Eintracht'
    

]

# %%
for i in range(len(Laliga_list)):
    df7["name"] = df7["name"].str.replace(Laliga_list[i], "")

# %%
df7
# Out:
#                      name  age position1 position2    Apps    Mins  Goals  \
# 0           Lionel Messi    35    AM(CR)        FW   29(2)  2508.0   27.0
# 1      Cristiano Ronaldo    37      M(L)        FW      30  2545.0   31.0
# 3            Gareth Bale    33    M(CLR)        FW   24(3)  2073.0   15.0
# 6         Alexis Sánchez    33    M(CLR)        FW   27(7)  2386.0   19.0
# 7                 Neymar    30   AM(CLR)        FW   19(7)  1742.0    9.0
# 13        Ángel Di María    34    M(CLR)        FW   27(7)  2384.0    4.0
# 15         Karim Benzema    34        FW             34(1)  2779.0   17.0
# 19           Carlos Vela    33    M(CLR)        FW   35(2)  3116.0   15.0
# 21                  Isco    30    M(CLR)        FW   23(9)  2001.0    8.0
# 23           Diego Costa    34        FW             34(1)  2965.0   27.0
# 30         Cesc Fàbregas    35     M(CL)        FW   28(7)  2446.0    8.0
# 31          Aritz Aduriz    41        FW             26(5)  2410.0   15.0
# 42          Iker Muniain    29   AM(CLR)             32(3)  2730.0    7.0
# 43     Antoine Griezmann    31   AM(CLR)        FW   31(4)  2666.0   16.0
# 47        Jonathan Viera    33   AM(CLR)        FW       1    79.0    0.0
# 65                Nolito    36    AM(CL)            24(11)  2264.0   12.0
# 67                 Pedro    35    M(CLR)        FW   28(9)  2367.0   15.0
# 74       Fabián Orellana    36   AM(CLR)             22(8)  1956.0    5.0
# 90           Oriol Riera    36        FW             35(2)  3022.0   13.0
# 98    Giovani dos Santos    33   AM(CLR)        FW   26(4)  2205.0   10.0
# 102              Charles    38        FW             29(1)  2349.0   12.0
# 106         Carlos Bacca    36        FW             27(7)  2290.0   14.0
# 111       Nordin Amrabat    35    M(CLR)        FW      15  1314.0    2.0
# 112        Sergio García    39    M(CLR)        FW      37  3259.0   11.0
# 115                 Miku    37        FW              3(2)   292.0    2.0
# 120       Ikechukwu Uche    38        FW             19(7)  1657.0   13.0
# 124               Vitolo    33    M(CLR)        FW   25(4)  2198.0    4.0
# 125          Raúl García    36    M(CLR)        FW  18(16)  1710.0    9.0
# 131          Javi Guerra    40        FW                37  3161.0   15.0
# 132           Arda Turan    35   AM(CLR)             22(8)  1932.0    3.0
# 137           Ibai Gómez    32    AM(LR)             6(12)   685.0    8.0
# 141     Cristhian Stuani    36   AM(CLR)        FW   28(6)  2574.0    6.0
# 149        Javier Aquino    32     AM(R)             18(9)  1695.0    1.0
# 155     Roque Santa Cruz    41        FW             24(7)  2140.0    6.0
# 161  Emiliano Armenteros    36   AM(CLR)             27(2)  2248.0    4.0
# 176     Youssef El Arabi    35     AM(C)        FW   34(2)  2801.0   12.0
# 182                Jonas    38   AM(CLR)        FW   23(8)  2097.0   10.0
# 188          David Villa    40     AM(L)        FW   32(4)  2431.0   13.0
# 190        Fede Cartabia    29   AM(CLR)             16(9)  1423.0    0.0
# 191     Joaquín Larrivey    38        FW            24(11)  2415.0   12.0
# 202          Manu Molina    30     AM(R)              0(1)    31.0    0.0
# 206         David Barral    39        FW             25(7)  2255.0    7.0
# 207       Roberto Torres    33   AM(CLR)             25(8)  2282.0    5.0
# 213                 Suso    28   AM(CLR)        FW   26(7)  2265.0    3.0
# 234        Diego Perotti    34    M(CLR)        FW    3(7)   403.0    1.0
# 235       Manu Trigueros    31    M(CLR)        FW  23(10)  2017.0    1.0
# 242         Rubén Castro    41    AM(LR)        FW   22(3)  2019.0   10.0
# 248         Ángel Lafita    38    M(CLR)        FW   22(7)  1870.0    7.0
# 249          Iago Falque    32   AM(CLR)        FW   26(2)  2001.0    3.0
# 258        Kevin Gameiro    35        FW            20(15)  1890.0   14.0
# 263            Kike Sola    36        FW              2(3)   226.0    1.0
# 274         Jorge Molina    40        FW             25(7)  2352.0    9.0
# 275       Jonathan Viera    33   AM(CLR)        FW   18(8)  1725.0    5.0
# 276       Gonzalo Castro    38    AM(LR)        FW  12(11)  1022.0    2.0
# 281         Dorlan Pabón    34   AM(CLR)        FW   11(2)   913.0    3.0
# 282           Carles Gil    29    AM(CR)             29(3)  2524.0    1.0
# 284     Víctor Casadesús    37     AM(C)        FW   13(1)  1051.0    1.0
# 293         Paco Alcácer    29     AM(R)        FW   17(6)  1542.0    6.0
# 295     Imanol Agirretxe    35        FW            21(10)  1960.0    8.0
#
#      Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 0       11.0  5.0   2.4  4.6    8.34          0
# 1        9.0  7.2   1.6  2.2    8.27          0
# 3       12.0  3.3   1.5  2.1    7.75          0
# 6       10.0  1.9   1.4  1.1    7.54          0
# 7        8.0  2.6   1.6  3.0    7.51          0
# 13      17.0  1.8   2.6  1.4    7.46          0
# 15       9.0  2.9   1.8  0.5    7.44          0
# 19      12.0  2.2   2.1  2.0    7.42          0
# 21       6.0  1.4   2.2  2.1    7.41          0
# 23       3.0  3.1   1.3  1.7    7.40          0
# 30      12.0  1.4   1.6  0.7    7.32          0
# 31       7.0  2.6   1.0  0.7    7.32          0
# 42       3.0  1.5   0.9  2.7    7.23          0
# 43       3.0  3.2   1.0  0.6    7.22          0
# 47       0.0  1.0   0.0  5.0    7.21          0
# 65       2.0  2.3   1.4  1.3    7.13          0
# 67       8.0  1.9   1.0  0.7    7.13          0
# 74       6.0  1.3   1.5  1.4    7.10          0
# 90       0.0  2.1   0.9  0.4    7.05          0
# 98       8.0  1.9   1.4  0.9    7.03          0
# 102      3.0  2.2   1.1  0.3    7.02          0
# 106      5.0  1.9   1.0  0.9    7.01          0
# 111      4.0  2.1   1.7  2.3    7.00          0
# 112      8.0  2.0   1.9  1.8    7.00          0
# 115      1.0  1.2   0.8  0.8    6.99          0
# 120      2.0  1.6   0.9  0.4    6.98          0
# 124      6.0  1.1   1.3  1.1    6.97          0
# 125      3.0  1.8   0.5  0.2    6.97          0
# 131      1.0  2.3   0.6  0.4    6.96          0
# 132      4.0  1.1   1.1  1.3    6.96          0
# 137      2.0  2.6   1.3  0.7    6.94          0
# 141      2.0  1.5   0.6  0.6    6.94          0
# 149      4.0  0.7   1.0  1.1    6.93          0
# 155      2.0  1.6   1.0  0.6    6.92          0
# 161      3.0  1.5   1.7  0.8    6.91          0
# 176      2.0  2.6   0.8  0.9    6.88          0
# 182      1.0  2.8   0.7  0.6    6.86          0
# 188      4.0  2.1   0.8  0.3    6.85          0
# 190      1.0  1.8   1.1  1.6    6.85          0
# 191      4.0  1.9   0.7  0.1    6.85          0
# 202      1.0  0.0   2.0  0.0    6.83          0
# 206      0.0  2.0   0.7  0.6    6.82          0
# 207      3.0  1.6   1.8  0.5    6.82          0
# 213      7.0  1.9   1.0  1.7    6.81          0
# 234      1.0  1.1   1.0  1.6    6.77          0
# 235      1.0  1.0   0.9  0.5    6.76          0
# 242      1.0  3.0   1.0  0.6    6.76          0
# 248      1.0  1.4   0.7  1.0    6.75          0
# 249      2.0  1.4   1.3  0.7    6.75          0
# 258      3.0  1.5   0.8  0.5    6.73          0
# 263      0.0  1.4   0.0  0.6    6.72          0
# 274      1.0  1.8   1.1  0.4    6.69          0
# 275      7.0  1.9   1.4  1.2    6.69          0
# 276      3.0  1.0   1.1  1.2    6.69          0
# 281      0.0  2.8   0.8  0.8    6.69          0
# 282      3.0  1.0   1.3  1.6    6.69          0
# 284      2.0  1.1   0.8  1.0    6.69          0
# 293      2.0  1.9   0.7  0.1    6.67          0
# 295      1.0  2.0   0.4  0.4    6.67          0

# %%
df7.to_csv("Laliga_13_14_of.csv")

# %%
df8 = pd.read_csv("13_14_of.csv")
df8
# Out:
#      Unnamed: 0                 name  age position1 position2    Apps  Mins  \
# 0             0       Franck Ribéry    39    AM(CL)        FW   18(4)  1643
# 1             2  Robert Lewandowski    34        FW       NaN   31(2)  2807
# 2             3     Roberto Firmino    31    M(CLR)        FW      33  2916
# 3             4          Marco Reus    33    M(CLR)        FW   26(4)  2221
# 4             5             Raffael    37    AM(CL)        FW      34  2999
# ..          ...                  ...  ...       ...       ...     ...   ...
# 305         304         Mario Gomez    37        FW       NaN    5(4)   498
# 306         306        Goran Pandev    39     M(CR)        FW  17(12)  1387
# 307         310       Victor Obinna    35        FW       NaN    4(6)   398
# 308         316        Josip Ilicic    34   AM(CLR)        FW   13(8)  1108
# 309         318        Valter Birsa    36    M(CLR)        FW   10(5)   756
#
#      Goals  Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 0       10       10  2.7   2.5  5.5    8.28          0
# 1       20        6  3.5   1.9  3.1    8.00          0
# 2       16       11  2.8   2.1  4.5    7.94          0
# 3       16       13  3.7   3.0  2.7    7.91          0
# 4       15        7  2.2   1.9  4.9    7.91          0
# ..     ...      ...  ...   ...  ...     ...        ...
# 305      3        1  1.4   0.3  0.2    6.72          0
# 306      7        4  0.9   1.0  0.7    6.71          0
# 307      2        0  1.8   0.7  0.9    6.71          0
# 308      3        1  1.9   1.0  0.9    6.71          0
# 309      2        0  1.5   1.2  1.0    6.70          0
#
# [310 rows x 14 columns]

# %%
df9 = pd.read_csv("./data/wc_2014/offensive.csv")
for i in range(len(Country)):
    df9["name"] = df9["name"].str.replace(Country[i], "")

# %%
df8["WC_Rating"] = 0
df8
# Out:
#      Unnamed: 0                 name  age position1 position2    Apps  Mins  \
# 0             0       Franck Ribéry    39    AM(CL)        FW   18(4)  1643
# 1             2  Robert Lewandowski    34        FW       NaN   31(2)  2807
# 2             3     Roberto Firmino    31    M(CLR)        FW      33  2916
# 3             4          Marco Reus    33    M(CLR)        FW   26(4)  2221
# 4             5             Raffael    37    AM(CL)        FW      34  2999
# ..          ...                  ...  ...       ...       ...     ...   ...
# 305         304         Mario Gomez    37        FW       NaN    5(4)   498
# 306         306        Goran Pandev    39     M(CR)        FW  17(12)  1387
# 307         310       Victor Obinna    35        FW       NaN    4(6)   398
# 308         316        Josip Ilicic    34   AM(CLR)        FW   13(8)  1108
# 309         318        Valter Birsa    36    M(CLR)        FW   10(5)   756
#
#      Goals  Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 0       10       10  2.7   2.5  5.5    8.28          0
# 1       20        6  3.5   1.9  3.1    8.00          0
# 2       16       11  2.8   2.1  4.5    7.94          0
# 3       16       13  3.7   3.0  2.7    7.91          0
# 4       15        7  2.2   1.9  4.9    7.91          0
# ..     ...      ...  ...   ...  ...     ...        ...
# 305      3        1  1.4   0.3  0.2    6.72          0
# 306      7        4  0.9   1.0  0.7    6.71          0
# 307      2        0  1.8   0.7  0.9    6.71          0
# 308      3        1  1.9   1.0  0.9    6.71          0
# 309      2        0  1.5   1.2  1.0    6.70          0
#
# [310 rows x 14 columns]

# %%
for i in range(len(df8)):
    for k in range(len(df9)):
        if df8["name"][i] == df9["name"][k]:
            df8["WC_Rating"][i] = df9["Rating"][k]

# %%
df8
# Out:
#      Unnamed: 0                 name  age position1 position2    Apps  Mins  \
# 0             0       Franck Ribéry    39    AM(CL)        FW   18(4)  1643
# 1             2  Robert Lewandowski    34        FW       NaN   31(2)  2807
# 2             3     Roberto Firmino    31    M(CLR)        FW      33  2916
# 3             4          Marco Reus    33    M(CLR)        FW   26(4)  2221
# 4             5             Raffael    37    AM(CL)        FW      34  2999
# ..          ...                  ...  ...       ...       ...     ...   ...
# 305         304         Mario Gomez    37        FW       NaN    5(4)   498
# 306         306        Goran Pandev    39     M(CR)        FW  17(12)  1387
# 307         310       Victor Obinna    35        FW       NaN    4(6)   398
# 308         316        Josip Ilicic    34   AM(CLR)        FW   13(8)  1108
# 309         318        Valter Birsa    36    M(CLR)        FW   10(5)   756
#
#      Goals  Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 0       10       10  2.7   2.5  5.5    8.28        0.0
# 1       20        6  3.5   1.9  3.1    8.00        0.0
# 2       16       11  2.8   2.1  4.5    7.94        0.0
# 3       16       13  3.7   3.0  2.7    7.91        0.0
# 4       15        7  2.2   1.9  4.9    7.91        0.0
# ..     ...      ...  ...   ...  ...     ...        ...
# 305      3        1  1.4   0.3  0.2    6.72        0.0
# 306      7        4  0.9   1.0  0.7    6.71        0.0
# 307      2        0  1.8   0.7  0.9    6.71        0.0
# 308      3        1  1.9   1.0  0.9    6.71        0.0
# 309      2        0  1.5   1.2  1.0    6.70        0.0
#
# [310 rows x 14 columns]

# %%
for i in range(len(df8)):
    if df8["WC_Rating"][i] == 0:
        df8.drop(i, inplace = True)

# %%
df8
# Out:
#      Unnamed: 0                         name  age position1 position2    Apps  \
# 6             9                Adrián Ramos    36        FW       NaN   30(2)
# 7            11                 Mario Götze    30    M(CLR)        FW   20(7)
# 8            13             Kevin De Bruyne    31    M(CLR)        FW      16
# 11           16              Julian Draxler    29   AM(CLR)        FW   25(1)
# 12           17                Arjen Robben    38    M(CLR)        FW   20(8)
# 15           25             Mario Mandzukic    36      M(L)        FW   21(9)
# 16           30         Klaas Jan Huntelaar    39        FW       NaN   17(1)
# 18           34               Admir Mehmedi    31    M(CLR)        FW   29(3)
# 20           38               Son Heung-Min    30    M(CLR)        FW   29(2)
# 21           42               Thomas Müller    33    M(CLR)        FW   25(6)
# 22           47          Eric Choupo-Moting    33    M(CLR)        FW  19(13)
# 29           73              Shinji Okazaki    36   AM(CLR)        FW   31(2)
# 32           94                Ivan Perisic    33    M(CLR)        FW   24(9)
# 34           98                  Ivica Olic    43    AM(LR)        FW   28(4)
# 40          126              Vedad Ibisevic    38        FW       NaN   25(2)
# 41          130                 Josip Drmic    30    AM(LR)        FW   30(3)
# 69            0                 Luis Suárez    35   AM(CLR)        FW      33
# 72            9                 Eden Hazard    31    M(CLR)        FW   32(3)
# 73           11                Wayne Rooney    37    M(CLR)        FW   27(2)
# 74           12                 David Silva    36    M(CLR)        FW   26(1)
# 75           17            Daniel Sturridge    33      M(R)        FW   26(3)
# 76           21             Raheem Sterling    27    M(CLR)        FW   24(9)
# 77           26              Olivier Giroud    36        FW       NaN      36
# 78           34                   Juan Mata    34   AM(CLR)       NaN   14(1)
# 79           35               Romelu Lukaku    29     AM(R)        FW   29(2)
# 81           46                     Willian    34   AM(CLR)       NaN   18(7)
# 86           73                   Loïc Rémy    35     M(LR)        FW   24(2)
# 87           75                  Edin Dzeko    36        FW       NaN   23(8)
# 89           87              Kevin Mirallas    35    M(CLR)        FW   28(4)
# 91           90               Wilfried Bony    33        FW       NaN   27(7)
# 93           99                Samuel Eto'o    41     M(CL)        FW   16(5)
# 94          109            Robin van Persie    39     AM(C)        FW   18(3)
# 97          140              Lukas Podolski    37   AM(CLR)        FW   14(6)
# 98          143               Adnan Januzaj    27   AM(CLR)       NaN  15(12)
# 103         174             Fernando Torres    38        FW       NaN  16(12)
# 105         179                   Juan Mata    34   AM(CLR)       NaN   11(2)
# 106         184              André Schürrle    32    M(CLR)        FW  15(15)
# 113         207               Danny Welbeck    31   AM(CLR)        FW  15(10)
# 120         245                  Bryan Ruiz    37    M(CLR)        FW    8(4)
# 126         283                Nacer Chadli    33    M(CLR)        FW   15(9)
# 128         297          Giorgos Karagounis    45     AM(C)       NaN    6(8)
# 189           7             James Rodríguez    31   AM(CLR)        FW   30(4)
# 191          22                  André Ayew    32    M(CLR)        FW   24(1)
# 195          46              Edinson Cavani    35    AM(LR)        FW   25(5)
# 201          65               Salomon Kalou    37   AM(CLR)        FW   36(2)
# 205         106            Max-Alain Gradel    34    M(CLR)        FW   10(8)
# 230         230            Ezequiel Lavezzi    37   AM(CLR)        FW   25(7)
# 240         270            Alejandro Bedoya    35     M(CR)        FW   24(7)
# 258          21                    Gervinho    35     M(LR)        FW   30(3)
# 261          34             Mario Balotelli    32        FW       NaN   25(5)
# 263          43               Alessio Cerci    35      M(R)        FW   35(2)
# 266          63               Dries Mertens    35   AM(CLR)        FW  21(12)
# 272          84             Gonzalo Higuaín    34        FW       NaN   28(4)
# 284         162                    Paulinho    36        FW       NaN      35
# 285         171              Miroslav Klose    44        FW       NaN   22(3)
# 287         180  Lazaros Christodoulopoulos    35   AM(CLR)        FW   20(7)
# 293         210               Victor Ibarbo    32    AM(LR)        FW  20(10)
#
#      Mins  Goals  Assists  SpG  KeyP  Drb  Rating  WC_Rating
# 6    2665     16        5  2.9   1.5  2.6    7.75       6.85
# 7    1830     10        8  1.9   1.4  3.6    7.72       7.00
# 8    1420      3        6  2.1   3.1  4.0    7.71       7.85
# 11   2154      2        6  1.8   2.3  4.1    7.69       6.27
# 12   1705     11        6  2.7   1.8  3.0    7.62       8.37
# 15   2028     18        4  2.5   1.0  0.7    7.50       7.80
# 16   1463     12        0  3.1   0.5  1.5    7.45       6.44
# 18   2618     12        4  2.5   1.0  3.6    7.40       7.13
# 20   2387     10        4  2.7   1.1  2.7    7.39       7.22
# 21   2173     13       10  2.3   2.0  1.0    7.36       7.98
# 22   2046     10        3  2.6   0.8  3.6    7.33       6.53
# 29   2719     15        1  2.2   0.8  1.4    7.23       6.54
# 32   2214     10        4  2.1   0.8  1.3    7.17       7.62
# 34   2409     14        5  2.3   0.8  1.3    7.16       6.81
# 40   2163     10        3  2.1   0.8  1.6    7.09       6.56
# 41   2666     17        3  2.0   1.0  2.2    7.08       6.91
# 69   2965     31       12  5.5   2.7  2.8    8.43       7.23
# 72   2898     14        7  2.1   2.7  3.8    7.68       7.44
# 73   2448     17       10  3.5   1.9  1.4    7.62       7.07
# 74   2174      7        9  2.0   3.2  1.1    7.57       6.69
# 75   2277     21        7  3.4   1.0  1.3    7.45       6.85
# 76   2221      9        5  1.4   1.6  2.8    7.40       6.54
# 77   3083     16        8  3.1   1.0  0.7    7.36       6.70
# 78   1231      6        4  1.9   2.3  0.9    7.31       7.12
# 79   2564     15        6  3.2   1.1  1.3    7.31       6.55
# 81   1680      4        2  1.8   2.6  1.5    7.25       6.33
# 86   2103     14        3  3.5   1.2  1.1    7.15       6.32
# 87   1993     16        1  3.3   0.6  0.4    7.15       6.99
# 89   2335      9        7  2.5   1.9  1.4    7.11       6.63
# 91   2473     16        4  3.2   0.7  0.7    7.10       6.84
# 93   1306      9        2  2.8   1.0  0.9    7.08       6.28
# 94   1584     12        3  3.0   0.8  0.7    7.06       7.29
# 97   1173      8        2  2.1   0.4  0.3    6.98       6.29
# 98   1641      4        3  1.7   1.1  1.9    6.96       6.67
# 103  1572      5        5  2.2   1.0  1.2    6.90       6.69
# 105   834      0        2  0.8   2.3  0.8    6.89       7.12
# 106  1327      8        2  1.9   1.0  0.6    6.88       6.99
# 113  1461      9        1  1.8   0.5  0.8    6.84       6.51
# 120   774      1        3  0.9   1.3  1.2    6.77       6.78
# 126  1455      1        3  1.4   1.3  1.0    6.70       6.33
# 128   657      0        0  0.6   0.9  0.6    6.67       6.90
# 189  2644      9       12  2.7   2.5  1.3    7.44       8.43
# 191  2121      6        3  2.3   1.1  1.2    7.28       7.27
# 195  2299     16        2  3.2   0.8  0.6    7.16       6.62
# 201  3116     16        6  2.6   1.4  2.0    7.10       6.48
# 205   978      5        5  1.7   1.3  1.3    7.00       6.45
# 230  1893      9        0  1.4   1.1  0.7    6.78       6.61
# 240  2205      5        0  1.4   0.8  0.2    6.70       6.65
# 258  2730      9       10  1.9   1.5  2.3    7.35       7.30
# 261  2294     14        6  5.1   1.1  1.9    7.31       6.47
# 263  3018     13       10  3.2   1.6  1.8    7.29       6.36
# 266  1912     11        5  2.6   1.6  1.5    7.21       6.74
# 272  2423     17        7  2.8   0.8  1.2    7.14       6.43
# 284  3144     15        3  2.8   1.3  1.2    6.96       6.51
# 285  2019      7        2  1.7   0.7  0.8    6.95       6.97
# 287  1834      2        2  2.2   1.7  1.7    6.93       7.04
# 293  2030      4        2  1.2   1.1  2.4    6.88       6.48

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

#준비물  
#csv파일안에 독립변수(x)로 쓸 데이터 : goals, assists, etc
#csv파일안에 종속변수(y)로 쓸 데이터 : wc_rating -> 월드컵 csv파일에서 따로 가져와서 병합해야함
x=df8[['Goals', 'Assists', 'SpG', 'KeyP', 'Drb']]
y=df8['WC_Rating']

#과적합 막기 위해서 트레이닝, 테스트 데이터 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.6, test_size=0.4)

#모델 생성 - 선형회귀 -> 결과안좋으면 로지스틱 회귀(소프트맥스) 함수 사용하는 것도 고려
model = LinearRegression()

#모델 훈련
model.fit(x_train, y_train)

#플롯으로 모델이 추측한 value & 테스트 value(정답) display
# plt.plot(model.predict(x_test, label=''))
# plt.plot(y_test.values.reshape(-1, 1), label='WC_Rating')
# plt.legend()

#오차 확인 -> 이거 결과 보고 가중치를 변경해야 겠지?
from sklearn.metrics import mean_absolute_error, mean_squared_error
#MAE 
mean_absolute_error(y_test, model.predict(x_test))
#MSE
MSE = mean_squared_error(y_test, model.predict(x_test))
#RMSE - 다른건 더 찾아보도록
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 0.5347489426462205

# %%
MSE
# Out:
# 0.2859564316612509
